# %% [markdown]
# <a href="https://colab.research.google.com/github/veda0696-stack/DL-assignment/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Optimized Character Level RNN Text Generation
"""

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.optimizers import Adam

# -------------------------
# Input Text
# -------------------------
text = "The beautiful girl whom I met last time is very intelligent also"

# -------------------------
# Character Encoding
# -------------------------
chars = sorted(set(text))
char_to_index = {c: i for i, c in enumerate(chars)}
index_to_char = {i: c for i, c in enumerate(chars)}
vocab_size = len(chars)

# -------------------------
# Create Sequences
# -------------------------
seq_length = 5
X, y = [], []

for i in range(len(text) - seq_length):
    X.append([char_to_index[c] for c in text[i:i + seq_length]])
    y.append(char_to_index[text[i + seq_length]])

X = np.array(X)
y = np.array(y)

# One-hot encoding
X = tf.one_hot(X, vocab_size)
y = tf.one_hot(y, vocab_size)

# -------------------------
# Build Optimized RNN Model
# -------------------------
model = Sequential([
    SimpleRNN(
        units=64,
        activation='tanh',   # better than relu for RNN
        input_shape=(seq_length, vocab_size)
    ),
    Dense(vocab_size, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# -------------------------
# Train Model
# -------------------------
model.fit(X, y, epochs=100, batch_size=16, verbose=2)

# -------------------------
# Text Generation Function
# -------------------------
def generate_text(model, start_string, length=50, temperature=1.0):
    generated = start_string

    for _ in range(length):
        input_seq = [char_to_index[c] for c in generated[-seq_length:]]
        input_seq = np.array(input_seq).reshape(1, seq_length)
        input_seq = tf.one_hot(input_seq, vocab_size)

        predictions = model.predict(input_seq, verbose=0)[0]
        predictions = np.log(predictions + 1e-8) / temperature
        probabilities = np.exp(predictions) / np.sum(np.exp(predictions))

        next_index = np.random.choice(len(probabilities), p=probabilities)
        generated += index_to_char[next_index]

    return generated

# -------------------------
# Generate Text
# -------------------------
start_seq = "The beautiful girl whom I met "
generated_text = generate_text(model, start_seq, length=50, temperature=0.8)

print("\nGenerated Text:")
print(generated_text)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         5,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 21)             │         1,365 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,869 (26.83 KB)
#  Trainable params: 6,869 (26.83 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4/4 - 3s - 654ms/step - accuracy: 0.0508 - loss: 3.0338
# Epoch 2/100
# 4/4 - 0s - 23ms/step - accuracy: 0.4068 - loss: 2.2081
# Epoch 3/100
# 4/4 - 0s - 33ms/step - accuracy: 0.5424 - loss: 1.6589
# Epoch 4/100
# 4/4 - 0s - 32ms/step - accuracy: 0.7288 - loss: 1.2385
# Epoch 5/100
# 4/4 - 0s - 17ms/step - accuracy: 0.8814 - loss: 0.8652
# Epoch 6/100
# 4/4 - 0s - 15ms/step - accuracy: 0.9492 - loss: 0.5926
# Epoch 7/100
# 4/4 - 0s - 15ms/step - accuracy: 0.9661 - loss: 0.4388
# Epoch 8/100
# 4/4 - 0s - 20ms/step - accuracy: 0.9492 - loss: 0.2978
# Epoch 9/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1936
# Epoch 10/100
# 4/4 - 0s - 15ms/step - accuracy: 0.9831 - loss: 0.1392
# Epoch 11/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0899
# Epoch 12/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0771
# Epoch 13/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0527
# Epoch 14/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0398
# Epoch 15/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 16/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 17/100
# 4/4 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0229
# Epoch 18/100
# 4/4 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0199
# Epoch 19/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 20/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0151
# Epoch 21/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 22/100
# 4/4 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 23/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 24/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0108
# Epoch 25/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0100
# Epoch 26/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0094
# Epoch 27/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 28/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0083
# Epoch 29/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0078
# Epoch 30/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 31/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 32/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0068
# Epoch 33/100
# 4/4 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 34/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 35/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 36/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 37/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 38/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 39/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 40/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0048
# Epoch 41/100
# 4/4 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 42/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 43/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0043
# Epoch 44/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0042
# Epoch 45/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 46/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 47/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0038
# Epoch 48/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0036
# Epoch 49/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 50/100
# 4/4 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.0034
# Epoch 51/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0033
# Epoch 52/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0032
# Epoch 53/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0031
# Epoch 54/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 55/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 56/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 57/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0028
# Epoch 58/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 59/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 60/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 61/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 62/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 63/100
# 4/4 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 64/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 65/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 66/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 67/100
# 4/4 - 0s - 35ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 68/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0021
# Epoch 69/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 70/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 71/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0020
# Epoch 72/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 73/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 74/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 75/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 76/100
# 4/4 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 77/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 78/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 79/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 80/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 81/100
# 4/4 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 82/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 83/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 84/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 85/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 86/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 87/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 88/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 89/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 90/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 91/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 92/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 93/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0013
# Epoch 94/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 95/100
# 4/4 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 96/100
# 4/4 - 0s - 34ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 97/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 98/100
# 4/4 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 99/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 100/100
# 4/4 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0011
#
# Generated Text:
# The beautiful girl whom I met last time is very intelligent also utmmels aety is
